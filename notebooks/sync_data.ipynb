# %%
ip_address = "194.68.245.107"
port_number = "22162"
username = "root"
identity_file = "/Users/ishiz/.ssh/id_ed25519"
local_path = "/Users/ishiz/pyworks/competitions/atma_udemy/data/raw/input"
remote_path = "/workspace/atma_udemy/data/raw"

# %%
# !scp -r -P {port_number} -i {identity_file} {local_path} {username}@{ip_address}:{remote_path}
